# %% [markdown]
# # 🎓 AICE Associate 모의고사 10회
# ## 제조 공정 품질(불량) 판정 · 이진분류 (14문항)
#
# ---
#
# **안내사항:**
# - 각 문제를 순서대로 풀어주세요.
# - 셋업 셀을 반드시 먼저 실행한 후 문제를 풀어주세요.
# - 답안은 지정된 셀에 작성하고, 오류정정·빈칸채우기 문항은 제공된 코드를 수정/완성하세요.
# - 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인할 수 있습니다.
#
# ---

# %% [markdown]
# ## 📚 참고 자료 (오픈북)
#
# 시험 중 아래 공식 문서를 참고할 수 있습니다. 링크 클릭 시 리디렉션 알림 화면이 나타나면, 화면의 URL을 한 번 더 클릭하세요.
#
# | 라이브러리 | 공식 문서 |
# |-----------|----------|
# | **Pandas** | https://pandas.pydata.org/docs/index.html |
# | **NumPy** | https://numpy.org/doc/stable/user/index.html#user |
# | **Scikit-learn** | https://scikit-learn.org/stable/user_guide.html |
# | **TensorFlow / Keras** | https://www.tensorflow.org/api_docs/python/tf |
# | **Seaborn** | https://seaborn.pydata.org/index.html |
#
# ---

# %% [markdown]
# ## ⚙️ 셋업 (먼저 실행)
#
# 아래 코드를 먼저 실행한 후 문제를 풀어주세요.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 데이터 파일 준비 (첨부파일 형태 — 동일 경로에 csv 저장, df는 만들지 않음)
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/ashram68/aice-exam/main/data/exam-10/factory_quality.csv', 'factory_quality.csv')
print('데이터 파일(factory_quality.csv) 준비 완료 — 문제 2에서 pd.read_csv()로 읽어주세요.')

# %% [markdown]
# ---
# ## 〈 데이터 분석 (30점) 〉
#
# ## 문제 1. seaborn alias 'sns'로 불러오기  `5점`
#
# seaborn을 사용할 수 있게 별칭(alias)을 `sns`로 해서 불러오세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 2. 데이터 파일 읽어오기  `5점`
#
# pandas로 데이터 파일을 읽어온 뒤, 데이터프레임 변수명 `df`에 할당하고 첫 **4개 행**을 출력하세요. (파일명: `factory_quality.csv`)

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 3. 불량 여부별 평균 압력 (groupby)  `5점`
#
# - **(3-1)** groupby로 불량 여부(`defect`)별 평균 압력(`pressure`)을 구해 출력하세요. (대상: `df`)
# - **(3-2)** 불량(defect=1)의 평균 압력은 정상(0)보다 대체로 어떠한가요? (높다 / 낮다)

# %%
# (3-1) 여기에 답안코드를 작성하고 실행하세요


# (3-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 4. 온도-진동 관계 jointplot  `5점`
#
# - **(4-1)** seaborn의 jointplot으로 공정 온도(`temperature`)와 진동(`vibration`)의 분포·관계를 불량 여부별로 그리세요. (X축=`temperature`, Y축=`vibration`, hue=`defect`)
# - **(4-2)** 불량(defect=1) 제품은 주로 온도·진동이 (높은 / 낮은) 영역에 분포하나요?

# %%
# (4-1) 여기에 답안코드를 작성하고 실행하세요


# (4-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 5. 생산 라인별 불량률 pointplot  `5점`
#
# - **(5-1)** seaborn의 pointplot으로 생산 라인(`machine`)별 불량률을 그리세요. (X축=`machine`, Y축=`defect`, defect 평균=불량률)
# - **(5-2)** 불량률이 가장 높은 생산 라인은 무엇인가요?

# %%
# (5-1) 여기에 답안코드를 작성하고 실행하세요


# (5-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 6. 타겟 클래스 분포 (value_counts)  `5점`
#
# - **(6-1)** `value_counts()` 함수로 `defect`의 클래스별 개수를 출력하세요. (대상: `df`)
# - **(6-2)** 불량(defect=1)에 해당하는 데이터는 총 몇 건인가요?

# %%
# (6-1) 여기에 답안코드를 작성하고 실행하세요


# (6-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 〈 데이터 전처리 (30점) 〉
#
# ## 문제 7. 진동 IQR 이상치 처리 (오류 정정)  `8점`
#
# 진동(`vibration`)에서 이상치가 발견되었습니다. IQR 기준으로 처리하세요.
# - **(7-1)** 아래 코드에 오류가 있습니다. 코드의 오류를 정정하세요.
#   - 대상: `df` / IQR = Q3 − Q1, 상한 = Q3 + 1.5·IQR, 하한 = Q1 − 1.5·IQR
#   - 진동이 상한 초과 또는 하한 미만인 행을 삭제 → `df_temp`에 저장
# - **(7-2)** 이상치 처리로 삭제된 행은 총 몇 개인가요?

# %%
# (7-1) 아래 코드의 오류를 정정하고 실행하세요
q1 = df["vibration"].quantile(0.25)
q3 = df["vibration"].quantile(0.75)
iqr = q1 - q3                              # ← 오류: IQR = Q3 - Q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
df_temp = df.drop( df["vibration"] > upper )   # ← 오류: 조건 인덱싱, 상·하한 모두 반영


# (7-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 8. 결측치 처리 (빈칸 채우기)  `7점`  ✏️ 빈칸 채우기
#
# 수치형 컬럼은 각 컬럼의 **중앙값**으로, 범주형(object) 컬럼은 각 컬럼의 **최빈값**으로 결측치를 채우세요.
# - 대상: `df_temp` / 아래 빈칸(`#8-1`, `#8-2`)을 채우고 실행하세요
# - **(8-2 추가)** `df_temp`의 결측치 처리 **전** 총 결측치 개수는 몇 개인가요?

# %%
# (8) 빈칸을 채우고 실행하세요
print("처리 전:", df_temp.isnull().sum().sum())
num_cols = df_temp.select_dtypes(include="number").columns
cat_cols = df_temp.select_dtypes(include="object").columns
for col in num_cols:
    df_temp[col] = df_temp[col].fillna( df_temp[col].____() )       # #8-1
for col in cat_cols:
    df_temp[col] = df_temp[col].fillna( df_temp[col].____()[0] )    # #8-2
print("처리 후:", df_temp.isnull().sum().sum())


# (8-1) #8-1 답 / (8-2) #8-2 답 / 처리 전 결측 개수: 여기에 입력(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 9. 원-핫 인코딩 (빈칸 채우기)  `8점`  ✏️ 빈칸 채우기
#
# - 대상: `df_temp` / 범주형 컬럼 `'machine'`을 원-핫 인코딩하고 결과를 `df_preset`에 저장
# - 아래 빈칸(`#9-1`, `#9-2`)을 채우고 실행하세요
# - **(9-2 추가)** `df_preset`의 전체 컬럼 개수는 총 몇 개인가요?

# %%
# (9) 빈칸을 채우고 실행하세요
df_preset = pd.____(data=df_temp, ____=["machine"])   # #9-1 / #9-2
df_preset.info()


# (9-1) #9-1 답 / (9-2) #9-2 답 / 컬럼 개수: 여기에 입력(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 10. 데이터 분리 + 스케일링 (오류 정정)  `7점`
#
# - **(10-1)** 아래 코드에 오류가 있습니다. 코드의 오류를 정정하세요.
#   - 대상: `df_preset`, 타겟=`defect`, 나머지=피처(X) / 훈련:검증 = 80:20, 클래스 비율 유지(stratify), random_state=42
#   - MinMaxScaler를 훈련데이터에 학습·변환하고, 검증데이터에는 학습된 기준만 적용
# - **(10-2)** 분할된 검증데이터(`X_valid`)의 행 개수는 몇 개인가요?

# %%
# (10-1) 아래 코드의 오류를 정정하고 실행하세요
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X = df_preset.drop("defect", axis=1)
y = df_preset["defect"]
X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)
mm = MinMaxScaler()
X_train = mm.transform(X_train)        # ← 오류: 훈련은 학습·변환
X_valid = mm.fit_transform(X_valid)    # ← 오류: 검증은 변환만
print(X_valid.shape)


# (10-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 〈 AI 모델링 (40점) 〉
#
# ## 문제 11. LogisticRegression + RandomForest 모델  `10점`
#
# 불량 여부(`defect`)를 예측하는 머신러닝 분류 모델을 만들려고 합니다.
# - **(11-1)** LogisticRegression 모델을 `lr`에 저장: `max_iter=1000`, `random_state=42`, 훈련데이터로 fit
# - **(11-2)** RandomForestClassifier 모델을 `rf`에 저장: 최대 깊이=5, `min_samples_split=3`, `random_state=42`, 훈련데이터로 fit

# %%
# (11-1) 여기에 답안코드를 작성하고 실행하세요


# (11-2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 12. 모델 성능 평가 (오류 정정)  `10점`
#
# - **(12-1)** 아래 코드에 오류가 있습니다. 코드의 오류를 정정하세요.
#   - 성능 평가는 검증데이터셋을 활용 / 두 모델의 정확도(accuracy)와 F1-score를 각각 구해 출력
# - **(12-2)** 두 모델의 성능을 비교했을 때(F1이 높을수록 우수) 더 우수한 모델은 무엇인가요?

# %%
# (12-1) 아래 코드의 오류를 정정하고 실행하세요
y_pred_lr = lr.predict(X_train)
y_pred_rf = rf.predict(X_valid)
from sklearn.metrics importaccuracy, f1
lr_acc = accuracy(y_valid, y_pred_lr);  lr_f1 = f1(y_valid, y_pred_lr)
rf_acc = accuracy(y_valid, y_pred_rf);  rf_f1 = f1(y_valid, y_pred_rf)
print(lr_acc, lr_f1, rf_acc, rf_f1)


# (12-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 13. 딥러닝 이진분류 모델 구축 (softmax 2)  `10점`
#
# 토폴로지와 가이드를 참고해 딥러닝 모델을 직접 구현하고 학습하세요. (먼저 [셋업] 셀 실행)
# - 타겟 `y_train`, `y_valid`를 `to_categorical`로 2클래스 원-핫 인코딩 (이진분류이지만 2유닛 softmax)
# - 히든 `activation='relu'`, 출력 `activation='softmax'`(2클래스)
# - compile: `optimizer='adam'`, `loss='categorical_crossentropy'`, `metrics=['accuracy']`
# - `es = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)`
# - `checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)`
# - fit: `epochs=50, batch_size=128, validation_data=(X_valid, y_valid), callbacks=[es, checkpoint]` → `history`
# - 학습 후 `history`로 정확도(accuracy / val_accuracy) 곡선 출력
#
# **⊿ 모델 토폴로지**
#
# `Input → Dense(64, relu) → Dropout(0.3) → Dense(32, relu) → Dense(2, softmax)`
#
# 위 모델 구조를 그림으로 나타내면 다음과 같습니다.
#
# ![딥러닝 모델 토폴로지](https://raw.githubusercontent.com/ashram68/aice-exam/main/assets/topology/exam-10_topology.jpg)

# %%
# [셋업] 먼저 실행하세요
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
tf.random.set_seed(42)

# %%
# (13) 여기에 답안코드를 작성하고 실행하세요 (원-핫(2) -> 콜백 -> 모델 -> 컴파일 -> 학습 -> 정확도 곡선)

# %% [markdown]
# ---
# ## 문제 14. 신규 제품 불량 여부 예측 시뮬레이션  `10점`
#
# `checkpoint`가 저장한 `best_model.keras`를 `load_model`로 불러와 신규 제품 3건의 불량 여부를 예측하세요.
# - 아래 `new_data`(3건)는 그대로 실행하세요
# - 학습과 동일한 스케일러(`mm`)로 변환한 뒤 예측
# - softmax 예측 결과를 `argmax`로 클래스(0=정상 / 1=불량)로 변환해 출력

# %%
# 신규 데이터 (제공) — 열 순서: [temperature, pressure, vibration, rotation_speed,
#  humidity, operation_hours, machine_A, machine_B, machine_C]
new_data = np.array([
    [92.0, 135.0, 5.5, 1450, 55.0, 13.0, 0, 0, 1],   # 고온·고압·고진동·C라인·장시간
    [70.0, 105.0, 1.6, 1520, 40.0,  6.0, 1, 0, 0],   # 정상 범위·A라인
    [78.0, 118.0, 2.6, 1480, 48.0,  9.0, 0, 1, 0],   # 중간·B라인
])

# (14) 여기에 답안코드를 작성하고 실행하세요 (load_model -> mm.transform -> 예측 -> argmax -> 정상/불량 출력)

# %% [markdown]
# ---
# ### 모든 문항이 완료되었습니다. 수고하셨습니다. 🎉
#
# 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인하세요.
