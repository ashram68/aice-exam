# %% [markdown]
# # 🎓 AICE Associate 모의고사 3회
# ## 중고차 판매 가격 예측 · 회귀 (14문항)
#
# ---
#
# **안내사항:**
# - 각 문제를 순서대로 풀어주세요.
# - 사전 코드를 반드시 먼저 실행한 후 문제를 풀어주세요.
# - 답안은 지정된 변수명에 저장해주세요.
# - 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인할 수 있습니다.
#
# ---

# %% [markdown]
# ## 📚 참고 자료 (오픈북)
#
# 시험 중 아래 공식 문서를 참고할 수 있습니다. 링크 클릭 시 리디렉션 알림 화면이 나타나면, 화면의 URL을 한 번 더 클릭하세요.
#
# | 라이브러리 | 공식 문서 |
# |-----------|----------|
# | **Pandas** | https://pandas.pydata.org/docs/index.html |
# | **NumPy** | https://numpy.org/doc/stable/user/index.html#user |
# | **Scikit-learn** | https://scikit-learn.org/stable/user_guide.html |
# | **TensorFlow / Keras** | https://www.tensorflow.org/api_docs/python/tf |
# | **Seaborn** | https://seaborn.pydata.org/index.html |
#
# ---

# %% [markdown]
# ## ⚙️ 사전 코드 (반드시 실행)
#
# 아래 코드를 먼저 실행한 후 문제를 풀어주세요.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 데이터 파일 준비 (첨부파일 형태 — 동일 경로에 csv 저장, df는 만들지 않음)
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/ashram68/aice-exam/main/data/exam-03/car_price_reg.csv', 'car_price_reg.csv')
print('데이터 파일(car_price_reg.csv) 준비 완료 — 문제 2에서 pd.read_csv()로 읽어주세요.')

# %% [markdown]
# ---
# ## 〈 데이터 분석 (20점) 〉
#
# ## 문제 1. numpy alias 'np'로 불러오기  `5점`
#
# numpy는 수치 연산에 널리 사용되는 파이썬 라이브러리입니다.
# numpy를 사용할 수 있게 별칭(alias)을 `np`로 해서 불러오세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 2. 데이터 파일 읽어오기  `5점`
#
# pandas로 데이터 파일을 읽어온 뒤, 데이터프레임 변수명 `df`에 할당하고 첫 **4개 행**을 출력하세요.
# - 데이터프레임 변수명 : `df` / 데이터 파일명 : `car_price_reg.csv` (동일 경로)

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 3. 제조사(brand) 분포 countplot  `5점`
#
# 시각화를 통해 제조사(`brand`)의 분포를 파악하려 합니다.
# - **(3-1)** seaborn의 `countplot`으로 제조사(`brand`)의 분포를 그리세요. (대상: `df`, 색상 구분 `hue`: `fuel_type`)
# - **(3-2)** 출력된 그래프에서 매물이 가장 많은 제조사는 어디인가요?

# %%
# (3-1) 여기에 답안코드를 작성하고 실행하세요


# (3-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 4. 주행거리-가격 관계 lmplot (회귀선)  `5점`
#
# 주행거리(`mileage`)와 가격(`price`)의 관계를 회귀선과 함께 확인하려 합니다.
# 아래 가이드에 따라 seaborn의 `lmplot`으로 시각화하세요. (lmplot은 산점도와 회귀선을 함께 그려줍니다)
# - 대상 데이터프레임 : `df`
# - X축 : 주행거리(`mileage`), Y축 : 가격(`price`)
# - 회귀선의 색상을 `line_kws` 옵션으로 빨간색(`'red'`)으로 지정하세요

# %%
# (4) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 〈 데이터 전처리 (30점) 〉
#
# ## 문제 5. 주행거리 이상치 제거 + car_id 삭제  `8점`
#
# `lmplot`으로 확인한 결과, 주행거리(`mileage`)에서 비정상적으로 큰 이상치가 발견되었습니다.
# - 대상 데이터프레임 : `df`
# - 주행거리(`mileage`)가 **330000 이상**인 행(row)을 이상치로 보고 삭제하세요
# - 불필요한 차량ID(`car_id`) 컬럼을 삭제하세요
# - 전처리를 적용한 데이터프레임은 `data_temp` 변수명으로 저장하고 `shape`를 출력하세요

# %%
# (5) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 6. 결측치 처리 (오류 정정)  `7점`
#
# 데이터에 결측치가 있을 경우 AI 모델링의 성능이 저하될 수 있습니다. 결측치를 처리하세요.
# - **(6-1)** 아래 코드에 에러가 나고 있습니다. 코드의 오류를 정정하세요.
#   - 대상 데이터프레임 : `data_temp`
#   - 배기량(`engine_cc`)과 이전 소유주 수(`owner_count`) 컬럼의 결측치를 **중앙값(median)**으로 채우세요
#   - 전처리가 반영된 데이터프레임은 `data_na`에 저장하세요
# - **(6-2)** `engine_cc` 컬럼의 중앙값은 얼마인가요?

# %%
# (6-1) 아래 코드의 오류를 정정하고 실행하세요
print( '결측치 처리 전\n', data_temp.isnull().sum() )
data_temp['engine_cc'] = data_temp['engine_cc'].fillna(data_temp['engine_cc'].mean())      # ← 오류: 중앙값으로 정정
data_temp['owner_count'] = data_temp['owner_count'].fillna(data_temp['owner_count'].mean())  # ← 오류: 중앙값으로 정정
data_na = data_temp
print( '\n결측치 처리 후\n', data_na.isnull().total() )   # ← 오류: 합계 메서드로 정정


# (6-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 7. 원-핫 인코딩 (빈칸 채우기)  `7점`  ✏️ 빈칸 채우기
#
# - 대상 데이터프레임 : `data_na`
# - 원-핫 인코딩 대상 : `brand`, `fuel_type`, `transmission`, `accident`
# - 다중공선성 방지를 위해 첫 번째 더미 변수를 제거하세요 (`drop_first` 옵션)
# - 결과를 `data_preset`에 저장하고 `info()`로 검증하세요
# - 아래 코드 셀의 빈칸(`#7-1`, `#7-2`)을 채우고 실행하세요
# - **(7-3)** `data_preset`의 전체 컬럼 개수는 총 몇 개인가요?

# %%
# (7) 아래 빈칸(#7-1, #7-2)을 채우고 실행하세요
data_preset = pd.____(data=data_na, ____=['brand', 'fuel_type', 'transmission', 'accident'], drop_first=True)  # #7-1 / #7-2
data_preset.info()


# (7-1) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (7-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (7-3) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 8. 훈련/검증 분리 + RobustScaler  `8점`
#
# 모델 학습을 위해 훈련/검증 데이터셋을 분리한 뒤 스케일링하려고 합니다.
# - 대상 데이터프레임 : `data_preset`
# - 가격(`price`)을 레이블 `y`, 나머지를 피처 `X`로 할당하세요
# - 훈련:검증 = 80:20, 난수 시드 42로 분리하세요 (`X_train`, `X_valid`, `y_train`, `y_valid`)
# - `RobustScaler`를 `ss` 변수에 지정 → 훈련데이터로 학습·변환, 검증데이터는 변환만 적용하세요
# - 마지막에 `X_train`, `X_valid`의 shape를 출력하세요

# %%
# (8) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 〈 AI 모델링 (50점) 〉
#
# ## 문제 9. RandomForest + XGBoost 회귀 모델  `8점`
#
# 가격(`price`)을 예측하는 머신러닝 회귀 모델을 만들려고 합니다.
# - **(9-1)** RandomForest **회귀** 모델을 `rf` 변수에 저장하고 훈련셋으로 학습하세요
#   - `n_estimators=100`, `max_depth=5`, `min_samples_split=3`, `random_state=42`
# - **(9-2)** XGBoost **회귀** 모델을 `xgb` 변수에 저장하고 훈련셋으로 학습하세요
#   - `n_estimators=100`, `max_depth=4`, `learning_rate=0.1`, `random_state=42`

# %%
# (9-1) 여기에 답안코드를 작성하고 실행하세요


# (9-2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 10. 회귀 모델 평가 (오류 정정)  `8점`
#
# 앞서 학습시킨 RandomForest와 XGBoost 회귀 모델의 성능을 평가하려고 합니다.
# - **(10-1)** 아래 코드에 에러가 나고 있습니다. 코드의 오류를 정정하세요.
#   - 성능 평가는 검증데이터셋을 활용하세요
#   - RandomForest 예측을 `y_pred_rf`, XGBoost 예측을 `y_pred_xgb`에 저장하세요
#   - 각 모델의 MAE(평균절대오차)를 `rf_mae`, `xgb_mae`에 저장하고 출력하세요
# - **(10-2)** 두 모델의 MAE를 비교했을 때 더 우수한 모델은? (MAE가 작을수록 우수)

# %%
# (10-1) 아래 코드의 오류를 정정하고 실행하세요
from sklearn.metrics import mean_absolute      # ← 오류: MAE 함수명 정정
y_pred_rf = rf.pred(X_valid)                    # ← 오류: 예측 메서드명 정정
y_pred_xgb = xgb.pred(X_valid)                  # ← 오류: 예측 메서드명 정정
rf_mae = mean_absolute(y_valid, y_pred_rf)      # ← 오류: MAE 함수명 정정
xgb_mae = mean_absolute(y_valid, y_pred_xgb)
print(rf_mae, xgb_mae)


# (10-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 11. RandomForest 변수중요도 (오류 정정)  `8점`
#
# RandomForest 모델의 변수중요도를 파악하려고 합니다.
# - **(11-1)** 아래 코드에 에러가 나고 있습니다. 코드의 오류를 정정하세요.
#   - 변수중요도 점수와 변수 이름(`X.columns`)을 매핑하여 DataFrame `fi`를 만드세요
#   - 변수중요도 점수 기준 내림차순 정렬하고 top 10개만 선정하세요
#   - seaborn `barplot`으로 시각화하세요 (`x='importance'`, `y='feature'`, `palette='viridis'`)
# - **(11-2)** 가장 높은 중요도를 보이는 변수명을 쓰세요.

# %%
# (11-1) 아래 코드의 오류를 정정하고 실행하세요
fi = pd.DataFrame({'feature': X.columns, 'importance': rf.importances})   # ← 오류: 변수중요도 속성명 정정
fi = fi.sort_index('importance', ascending=False)[:10]                    # ← 오류: 값 기준 정렬 메서드로 정정
sns.barplot(x='importance', y='feature', data=fi, palette='viridis')


# (11-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ▶ **다음 문항을 풀기 전에 아래 코드를 실행하세요.**

# %%
# 다음 문항을 풀기 전에 아래 코드를 실행하세요.
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
tf.random.set_seed(1)

# %% [markdown]
# ---
# ## 문제 12. 딥러닝 회귀 모델 생성 및 학습  `8점`
#
# 가격(`price`)을 예측하는 딥러닝 회귀 모델을 만들려고 합니다. 아래 토폴로지와 가이드를 참고해 모델을 구성·학습하세요.
# - 하단 토폴로지와 동일한 모델을 구현하세요. 히든 `activation='relu'`, 출력 `activation='linear'`(1노드)
# - `EarlyStopping`으로 5 epoch 동안 `val_loss`가 향상되지 않으면 중지하고 `estop`에 저장하세요
# - `optimizer='adam'`, `loss='mean_squared_error'`, `metrics=['mae']`로 컴파일하세요 (회귀)
# - `batch_size=32`, `epochs=50`으로 학습하고 학습정보는 `history`에 저장하세요
#
# **⊿ 모델 토폴로지**
#
# `입력층 → Dense(64, relu) → Dropout(0.2) → Dense(32, relu) → Dense(16, relu) → Dense(1, linear)`
#
# 위 모델 구조를 그림으로 나타내면 다음과 같습니다.
#
# ![딥러닝 모델 토폴로지](https://raw.githubusercontent.com/ashram68/aice-exam/main/assets/topology/exam-03_topology.jpg)

# %%
# (12) 여기에 답안코드를 작성하고 실행하세요 (모델 구성 -> 컴파일 -> 학습)

# %% [markdown]
# ---
# ## 문제 13. 학습/검증 Loss 시각화  `8점`  ✏️ 빈칸 채우기
#
# matplotlib로 학습/검증 Loss의 변화를 그래프로 시각화하세요.
# - 1개의 그래프에 학습 Loss와 검증 Loss를 모두 표시하세요
# - 각각의 범례를 `'train_loss'`, `'val_loss'`로 표시하세요
# - 타이틀 `'Model Loss'`, X축 `'Epochs'`, Y축 `'Loss'`로 표시하세요
# - 아래 코드 셀의 빈칸(`#13-1`, `#13-2`)을 채우고 실행하세요

# %%
# (13) 아래 빈칸(#13-1, #13-2)을 채우고 실행하세요
plt.plot(____['loss'])         # #13-1
plt.plot(____['val_loss'])     # #13-1
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.____(['train_loss', 'val_loss'])   # #13-2
plt.show()


# (13-1) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (13-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 14. 모델 저장/로드 후 신규 매물 가격 예측  `10점`
#
# 학습한 딥러닝 모델을 저장한 뒤, `load_model()`로 불러와 신규 매물의 판매 가격을 예측하려고 합니다.
# - 아래 제시된 신규 매물 데이터(`new_raw`)는 그대로 실행하세요 (예측 대상)
# - 학습한 `model`을 `'car_price_model.keras'`로 저장한 뒤 `load_model()`로 불러오세요
# - `new_raw`를 학습 때와 동일하게 전처리하세요 (원-핫 인코딩 후 학습 피처 컬럼에 맞춰 정렬, 그 후 `ss`로 스케일링)
# - 불러온 모델로 각 매물의 예측 가격(만원)을 출력하세요

# %%
# 아래 신규 매물 데이터(new_raw)는 그대로 실행하세요
new_raw = pd.DataFrame([
    {'model_year':2021, 'mileage':35000, 'engine_cc':1600, 'owner_count':1,
     'brand':'Hyundai', 'fuel_type':'Gasoline', 'transmission':'Automatic', 'accident':'No'},
    {'model_year':2013, 'mileage':180000, 'engine_cc':2000, 'owner_count':3,
     'brand':'Kia', 'fuel_type':'Diesel', 'transmission':'Manual', 'accident':'Yes'},
])

# (14) 여기에 답안코드를 작성하고 실행하세요 (모델 저장 -> load_model -> new_raw 전처리 -> 예측 가격 출력)

# %% [markdown]
# ---
# ### 모든 문항이 완료되었습니다. 수고하셨습니다. 🎉
#
# 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인하세요.
