# %% [markdown]
# # 🎓 AICE Associate 모의고사 1회
# ## Titanic 데이터셋 분석 (15문항)
#
# ---
#
# **안내사항:**
# - 각 문제를 순서대로 풀어주세요.
# - 사전 코드를 반드시 먼저 실행한 후 문제를 풀어주세요.
# - 답안은 지정된 변수명에 저장해주세요.
# - 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인할 수 있습니다.
#
# ---

# %% [markdown]
# ## 📚 참고 자료 (오픈북)
#
# 시험 중 아래 공식 문서를 참고할 수 있습니다. 링크 클릭 시 리디렉션 알림 화면이 나타나면, 화면의 URL을 한 번 더 클릭하세요.
#
# | 라이브러리 | 공식 문서 |
# |-----------|----------|
# | **Pandas** | https://pandas.pydata.org/docs/index.html |
# | **NumPy** | https://numpy.org/doc/stable/user/index.html#user |
# | **Scikit-learn** | https://scikit-learn.org/stable/user_guide.html |
# | **TensorFlow / Keras** | https://www.tensorflow.org/api_docs/python/tf |
# | **Seaborn** | https://seaborn.pydata.org/index.html |
#
# ---

# %% [markdown]
# ## ⚙️ 사전 코드 (반드시 실행)
#
# 아래 코드를 먼저 실행한 후 문제를 풀어주세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# 데이터 로드 (GitHub raw URL)
df = pd.read_csv('https://raw.githubusercontent.com/ashram68/aice-exam/main/data/exam-01/titanic.csv')
print(f'데이터 로드 완료: {df.shape}')
df.head()

# %% [markdown]
# ---
# ## 〈 데이터 분석 (20점) 〉
#
# ## 문제 1. pandas alias 'pd'로 불러오기  `5점`
#
# pandas는 데이터 분석에 널리 사용되는 파이썬 라이브러리입니다.
#
# - pandas를 사용할 수 있게 별칭(alias)을 pd로 해서 불러오세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 2. 데이터 파일 읽어오기  `5점`
#
# AI 모델링을 위해 분석 및 처리할 데이터 파일을 읽어오려고 합니다.
#
# - pandas로 데이터 파일을 읽어온 뒤, 데이터프레임 변수명 `df`에 할당하고 첫 5개 행을 출력하세요.
# - 데이터프레임 변수명: `df`
# - 데이터 파일명: `titanic.csv`
# - csv 파일은 본 문제/답안지와 동일한 경로에 있습니다.

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ⚠ **다음 문항을 풀기 전에 아래 코드를 실행하세요.**
#
# ```python
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import warnings
# warnings.filterwarnings('ignore')
#
# # 한글 폰트 설정
# import matplotlib as mpl
# import matplotlib.font_manager as fm
# try:
#     font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
#     font = fm.FontProperties(fname=font_path).get_name()
#     mpl.rc('font', family=font)
# except:
#     pass
# plt.rcParams['axes.unicode_minus'] = False
# ```
#
# ---
# ## 문제 3. 객실 등급(Pclass)별 생존 분포 countplot  `5점`
#
# 시각화를 통해 객실 등급(Pclass)별 생존 여부(Survived)의 분포를 파악하려 합니다.
#
# **(3-1)** 아래 가이드에 따라 seaborn 라이브러리를 활용해서 시각화하세요.
# - 대상 데이터프레임: `df`
# - seaborn의 `countplot`으로 객실 등급별 생존자 수 분포를 그래프로 그리세요
# - X축: 객실 등급(`Pclass`), hue(색상 구분): 생존 여부(`Survived`)
#
# **(3-2)** 출력된 그래프에서 생존율이 가장 높았던 객실 등급(Pclass)은 몇 등급인가요?

# %%
# (3-1) 여기에 답안코드를 작성하고 실행하세요


# (3-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 4. Age-Fare 관계 scatterplot + Survived hue  `5점`
#
# 그래프를 통해 나이(Age)와 운임(Fare) 컬럼의 관계 및 생존 여부를 확인하려 합니다.
#
# 아래 가이드에 따라 `scatterplot`으로 시각화하세요.
# - 대상 데이터프레임: `df`
# - seaborn의 `scatterplot`으로 두 컬럼 간의 관계를 그래프로 그리세요
# - X축: 나이(`Age`), Y축: 운임(`Fare`)
# - 생존 여부(`Survived`)를 `hue`로 구분하여 표시하세요

# %%
# (4) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 〈 데이터 전처리 (30점) 〉
#
# ## 문제 5. AI 모델링에 불필요한 컬럼 삭제  `5점`
#
# 아래 가이드에 따라 컬럼을 삭제하세요.
# - 대상 데이터프레임: `df`
# - 삭제 대상: `PassengerId`(단순 식별자), `Name`(이름), `Ticket`(티켓 번호), `Cabin`(결측치가 너무 많음)
# - 컬럼이 삭제된 데이터프레임을 `data_temp`라는 변수명으로 저장하세요
# - `data_temp`의 컬럼 개수를 출력하세요

# %%
# (5) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 6. 결측치 처리 (오류 정정)  `6점`
#
# 데이터에 결측치가 있을 경우 AI 모델링의 성능이 저하될 수 있습니다.
#
# **(6-1)** 아래 코드는 에러가 나고 있습니다. **코드의 오류를 정정하세요.**
# - 대상 데이터프레임: `data_temp`
# - 나이(`Age`) 컬럼의 결측치는 **중앙값(median)** 으로 채우세요
# - 탑승항구(`Embarked`) 컬럼의 결측치는 **최빈값(mode)** 으로 채우세요
# - 전처리가 반영된 데이터프레임은 그대로 `data_temp`에 저장하세요
# - 결측치가 사라졌는지 확인하세요
#
# **오류 코드 (수정 대상):**
# ```python
# print('결측치 처리 전\n', data_temp.isnull().sum())
# data_temp['Age'] = data_temp['Age'].fillna(data_temp['Age'].mean())
# data_temp['Embarked'] = data_temp['Embarked'].fillna(data_temp['Embarked'].mode())
# print('\n결측치 처리 후\n', data_temp.isnull().sum())
# ```
#
# **(6-2)** Age 컬럼의 중앙값은 얼마인가요?

# %%
# (6-1) 여기에 코드의 오류를 정정하고 실행하세요


# (6-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 7. 원-핫 인코딩 (빈칸 채우기)  `6점`
#
# 원-핫 인코딩(One-Hot Encoding)은 범주형 데이터를 1과 0의 이진형 벡터로 변환하기 위해 사용하는 방법입니다.
#
# 아래 가이드에 따라 범주형 데이터를 이진형 벡터로 변환하는 코드를 완성하세요.
# - 대상 데이터프레임: `data_temp`
# - 원-핫 인코딩 대상: `'Gender'`, `'Embarked'`
# - 다중공선성 방지를 위해 첫 번째 더미 변수는 제거하세요 (`drop_first` 옵션)
# - 결과를 데이터프레임 변수명 `data_preset`에 저장
# - 결과 컬럼이 변환되었는지 `info()` 함수로 검증
#
# **빈칸 채우기 코드:**
# ```python
# data_preset = pd.<#7-1>(data=data_temp, <#7-2>=['Gender', 'Embarked'], drop_first=True)
# data_preset.info()
# ```
#
# **(7-1)** 위 코드의 첫 번째 빈칸에 들어갈 함수명은?
#
# **(7-2)** 위 코드의 두 번째 빈칸에 들어갈 옵션명은?

# %%
# 코드 셀: 빈칸을 채우고 실행하세요
# data_preset = pd.<#7-1>(data=data_temp, <#7-2>=['Gender', 'Embarked'], drop_first=True)
# data_preset.info()


# (7-1) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (7-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 8. 훈련/검증 데이터셋 분리  `6점`
#
# 모델링 후에 모델의 성능을 평가할 수 있도록 훈련과 검증 각각에 사용할 데이터셋을 분리하려고 합니다.
#
# 생존여부(`Survived`) 컬럼을 레이블값 `y`로, 나머지 컬럼을 피처값 `X`로 할당한 후 훈련데이터셋과 검증데이터셋으로 분리하세요.
# - 대상 데이터프레임: `data_preset`
# - 훈련/검증데이터셋 분리
# - 훈련 레이블: `y_train`, 훈련 피처: `X_train`
# - 검증 레이블: `y_valid`, 검증 피처: `X_valid`
# - 훈련/검증데이터셋 비율: 80:20
# - 훈련/검증의 생존여부 비율을 동일하게 하는 옵션(`stratify`) 설정
# - 난수 시드: 42
# - scikit-learn의 `train_test_split` 함수 활용

# %%
# (8) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 9. StandardScaler 오류 정정  `7점`
#
# 스케일링을 통해 데이터의 범위를 일정하게 맞추려고 합니다.
#
# **(9-1)** 아래 코드는 에러가 나고 있습니다. **코드의 오류를 정정하세요.**
# - `sklearn.preprocessing`에서 `StandardScaler` 함수를 import
# - `StandardScaler` 함수를 `ss` 변수에 지정
# - 훈련 데이터에 대해 `StandardScaler`를 학습시키고 변환을 적용
# - 검증 데이터에 학습된 스케일링 기준을 **그대로 적용** (⚠ fit하지 말 것!)
# - 스케일링된 검증 데이터의 가장 큰 값을 찾고, 반올림
#
# **오류 코드 (수정 대상):**
# ```python
# from sklearn.preprocessing import StandardScaler
# ss = StandardScaler()
# X_train = ss.fit_transform(X_train)
# X_valid = ss.fit_transform(X_valid)
# round(np.max(X_valid))
# ```
#
# **(9-2)** StandardScaler 적용 후 검증 데이터의 최댓값을 반올림한 결과는 무엇입니까?

# %%
# (9-1) 여기에 코드의 오류를 정정하고 실행하세요


# (9-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 〈 AI 모델링 (50점) 〉
#
# ## 문제 10. DecisionTree + RandomForest 모델 생성  `8점`
#
# 생존여부(`Survived`)를 예측하는 머신러닝 모델을 만들려고 합니다.
#
# DecisionTree와 RandomForest는 여러 규칙을 순차적으로 적용하면서 독립변수 공간을 분할하는 모형으로서, 분류와 회귀 분석에 모두 사용될 수 있습니다.
#
# **(10-1)** DecisionTree 모델의 하이퍼파라미터를 아래와 같이 구성하고, 변수에 저장하세요.
# - 트리의 최대 깊이(`max_depth`): 5
# - 노드 분할 최소 샘플 수(`min_samples_split`): 3
# - 리프 노드 최소 샘플 수(`min_samples_leaf`): 2
# - 난수 시드(`random_state`): 42
# - DecisionTree 모델을 `dt` 변수에 저장하세요
# - 앞서 분리한 훈련데이터셋으로 `fit` 함수를 사용해 학습시키세요
#
# **(10-2)** RandomForest 모델의 하이퍼파라미터를 아래와 같이 설정하고, 변수에 저장하세요.
# - 트리 개수(`n_estimators`): 100
# - 트리의 최대 깊이(`max_depth`): 5
# - 노드 분할 최소 샘플 수(`min_samples_split`): 3
# - 리프 노드 최소 샘플 수(`min_samples_leaf`): 2
# - 난수 시드(`random_state`): 42
# - RandomForest 모델을 `rf` 변수에 저장하세요
# - 앞서 분리한 훈련데이터셋으로 `fit` 함수를 사용해 학습시키세요

# %%
# (10-1) 여기에 답안코드를 작성하고 실행하세요


# (10-2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 11. RandomForest 변수중요도 분석 및 시각화  `7점`
#
# 모델의 해석력과 개선 방향을 이해하기 위해 RandomForest 모델의 변수중요도를 파악하려고 합니다.
#
# **(11-1)** 아래 가이드에 따라 모델의 변수중요도를 파악하고 시각화하세요.
# - RandomForest 모델(`rf`)의 변수중요도 점수와 변수 이름(`X.columns`)을 매핑하여 DataFrame을 만드세요
# - DataFrame 변수명: `fi`
# - 컬럼명: `'feature'`(변수명), `'importance'`(중요도 점수)
# - 변수중요도 점수를 기준으로 **내림차순 정렬**하세요
# - seaborn의 `barplot`으로 변수중요도 점수를 막대 그래프로 시각화하세요
# - X축: `'importance'`, Y축: `'feature'`
# - `palette='viridis'` 옵션을 사용하세요
#
# **(11-2)** 출력된 그래프에서 가장 높은 중요도를 보이는 변수명을 쓰세요.

# %%
# (11-1) 여기에 답안코드를 작성하고 실행하세요


# (11-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 12. 모델 평가 (Accuracy + F1 + Confusion Matrix)  `9점`
#
# 앞서 학습시킨 DecisionTree와 RandomForest 모델의 성능을 평가하려고 합니다.
#
# **(12-1)** 아래 가이드에 따라 각 모델의 Accuracy와 F1-score를 산출하세요.
# - 성능 평가는 검증데이터셋(`X_valid`, `y_valid`)을 활용하세요
# - DecisionTree 모델로 y값을 예측 → `y_pred_dt` 변수에 저장
# - 검증 정답(`y_valid`)과 예측값(`y_pred_dt`)의 Accuracy → `dt_acc` 변수에 저장
# - 검증 정답(`y_valid`)과 예측값(`y_pred_dt`)의 F1-score → `dt_f1` 변수에 저장
# - RandomForest 모델로도 동일하게 `y_pred_rf`, `rf_acc`, `rf_f1`을 구하세요
# - 2개 모델의 Accuracy와 F1-score를 출력하세요
#
# **(12-2)** 두 모델의 F1-score 결과를 비교했을 때, 성능이 더 우수한 모델은 무엇인가요?
#
# **(12-3)** RandomForest 모델의 혼동행렬(Confusion Matrix)을 seaborn heatmap으로 시각화하세요.
# - `sklearn.metrics`의 `confusion_matrix` 함수를 사용
# - seaborn의 `heatmap`을 사용
# - 옵션: `annot=True`, `fmt='d'`, `cmap='Blues'`
# - X축: `'Predicted'`, Y축: `'Actual'` 라벨 표시

# %%
# (12-1) 여기에 답안코드를 작성하고 실행하세요


# (12-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (12-3) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ⚠ **다음 문항을 풀기 전에 아래 코드를 실행하세요.**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ## 문제 13. 딥러닝 분류 모델 생성 및 학습  `12점`
#
# 생존여부(`Survived`)를 예측하는 딥러닝 모델을 만들려고 합니다.
#
# 아래 토폴로지와 가이드를 참고해서 모델링하고 학습을 수행하세요.
#
# **모델 토폴로지:**
# 입력층 → `Dense(64, relu)` → `Dropout(0.3)` → `Dense(32, relu)` → `Dense(16, relu)` → `Dense(1, sigmoid)`
#
# - tensorflow framework를 사용하고 위의 토폴로지와 동일한 딥러닝 모델을 구현하세요
# - 히든 레이어의 activation 함수는 `'relu'`, 마지막 출력층의 activation 함수는 `'sigmoid'` 사용
# - EarlyStopping: 10번의 epoch 동안 모니터링 지표(`val_loss`)가 향상되지 않으면 훈련을 중지, `restore_best_weights=True` 설정, `es` 변수에 저장
# - compile: optimizer=`adam`, metrics=`accuracy`, loss=`binary_crossentropy`
# - fit: `batch_size=32`, `epochs=50`, `validation_data` 옵션 사용, `callbacks` 옵션에 EarlyStopping(`es`) 적용
# - 학습정보는 `history` 변수에 저장

# %%
# (13) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 14. 학습/검증 Loss 시각화  `7점`
#
# 앞서 만든 딥러닝 모델의 일반화 성능(Generalization Performance)을 평가하려고 합니다.
#
# matplotlib 라이브러리를 활용해서, 학습 Loss와 검증 Loss의 변화를 그래프로 시각화하세요.
#
# - 1개의 그래프에 학습 Loss(`loss`)와 검증 Loss(`val_loss`) 2가지를 모두 표시하세요
# - 위 2가지 각각의 범례를 `'train_loss'`, `'val_loss'`로 표시하세요
# - 그래프의 타이틀은 `'Model Loss'`로 표시하세요
# - X축: `'Epochs'`, Y축: `'Loss'`

# %%
# (14) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 15. 새 승객 1명의 생존 여부 예측 시뮬레이션  `14점`
#
# 학습된 딥러닝 모델을 활용하여 새로운 승객 1명의 생존 여부를 예측하는 시뮬레이션을 수행하세요.
#
# **새로운 승객 정보:**
# 3등급 객실의 25세 남성, 가족 없이 혼자 탑승, 운임 10.5, Southampton 항구에서 탑승
#
# 아래는 새로운 승객 1명의 데이터를 2차원 NumPy 배열로 제공한 것입니다.
# 컬럼 순서는 `X.columns`의 순서와 동일하게 다음과 같습니다:
#
# ```python
# # 컬럼 순서: ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Gender_male', 'Embarked_Q', 'Embarked_S']
# new_passenger = np.array([[3, 25, 0, 0, 10.5, 1, 0, 1]])
# ```
#
# - 위에 주어진 `new_passenger` (NumPy 2차원 배열, shape=(1, 8))을 **그대로 사용**하세요
# - 훈련 데이터에서 학습한 `ss` 스케일러로 변환하세요 (⚠ `fit_transform` 사용 금지)
# - 변환된 배열은 `new_scaled` 변수에 저장하세요
# - 학습된 `model`로 생존 확률을 예측하세요
# - 예측 확률은 `pred_prob` 변수에 저장하세요
# - 예측 확률을 클래스로 변환하여 `pred_class` 변수에 저장하세요 (출력층이 sigmoid이므로 0.5 기준)
# - 예측 결과를 다음 형식으로 출력하세요:
#   - 생존 확률 (소수점 4자리)
#   - 예측 클래스 (0 또는 1)
#   - 예측 클래스가 1이면 `"이 승객은 생존할 것으로 예측됩니다."`, 0이면 `"이 승객은 사망할 것으로 예측됩니다."`

# %%
# (15) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 🎉 수고하셨습니다!
#
# 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인하세요.
