# %% [markdown]
# # 🎓 AICE Associate 모의고사 4회
# ## 멤버십 등급 예측 · 다중분류 (14문항)
#
# ---
#
# **안내사항:**
# - 각 문제를 순서대로 풀어주세요.
# - 사전 코드를 반드시 먼저 실행한 후 문제를 풀어주세요.
# - 답안은 지정된 변수명에 저장해주세요.
# - 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인할 수 있습니다.
#
# ---

# %% [markdown]
# ## 📚 참고 자료 (오픈북)
#
# 시험 중 아래 공식 문서를 참고할 수 있습니다. 링크 클릭 시 리디렉션 알림 화면이 나타나면, 화면의 URL을 한 번 더 클릭하세요.
#
# | 라이브러리 | 공식 문서 |
# |-----------|----------|
# | **Pandas** | https://pandas.pydata.org/docs/index.html |
# | **NumPy** | https://numpy.org/doc/stable/user/index.html#user |
# | **Scikit-learn** | https://scikit-learn.org/stable/user_guide.html |
# | **TensorFlow / Keras** | https://www.tensorflow.org/api_docs/python/tf |
# | **Seaborn** | https://seaborn.pydata.org/index.html |
#
# ---

# %% [markdown]
# ## ⚙️ 사전 코드 (반드시 실행)
#
# 아래 코드를 먼저 실행한 후 문제를 풀어주세요.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 데이터 파일 준비 (첨부파일 형태 — 동일 경로에 csv 저장, df는 만들지 않음)
import urllib.request
urllib.request.urlretrieve('https://raw.githubusercontent.com/ashram68/aice-exam/main/data/exam-04/customer_tier_mc.csv', 'customer_tier_mc.csv')
print('데이터 파일(customer_tier_mc.csv) 준비 완료 — 문제 2에서 pd.read_csv()로 읽어주세요.')

# %% [markdown]
# ---
# ## 〈 데이터 분석 (20점) 〉
#
# ## 문제 1. pandas alias 'pd'로 불러오기  `5점`
#
# pandas를 사용할 수 있게 별칭(alias)을 `pd`로 해서 불러오세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 2. 데이터 파일 읽어오기  `5점`
#
# pandas로 데이터 파일을 읽어온 뒤, 데이터프레임 변수명 `df`에 할당하고 첫 **4개 행**을 출력하세요.
# - 데이터프레임 변수명 : `df` / 데이터 파일명 : `customer_tier_mc.csv` (동일 경로)

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 3. 주문 수-리뷰 수 관계 jointplot  `5점`
#
# 주문 수(`num_orders`)와 리뷰 수(`num_reviews`)의 관계 및 각 분포를 함께 확인하려 합니다.
# 아래 가이드에 따라 seaborn의 `jointplot`으로 시각화하세요. (jointplot은 산점도와 각 변수의 분포를 함께 보여줍니다)
# - 대상 데이터프레임 : `df`
# - X축 : 주문 수(`num_orders`), Y축 : 리뷰 수(`num_reviews`)

# %%
# (3) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 4. 수치형 변수 상관관계 heatmap  `5점`
#
# 수치형 변수들 사이의 상관관계를 한눈에 파악하려 합니다.
# - **(4-1)** seaborn의 `heatmap`으로 시각화하세요. (대상: `df`)
#   - `df.corr(numeric_only=True)`로 수치형 변수 간 상관계수를 구한 뒤 heatmap으로 그리세요
#   - 각 칸에 상관계수 값을 표시하세요 (`annot=True`)
# - **(4-2)** 주문 수(`num_orders`)와 상관계수가 가장 높은(자기 자신 제외) 변수는 무엇인가요?

# %%
# (4-1) 여기에 답안코드를 작성하고 실행하세요


# (4-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 〈 데이터 전처리 (30점) 〉
#
# ## 문제 5. 불필요 컬럼 삭제  `8점`
#
# - 대상 데이터프레임 : `df`
# - AI 모델링에 불필요한 컬럼을 삭제하세요: `cust_id`(단순 식별자), `signup_date`(가입일자 문자열)
# - 컬럼이 삭제된 데이터프레임을 `data_temp` 변수명으로 저장하고 `shape`를 출력하세요

# %%
# (5) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 6. 결측치 처리 (오류 정정)  `7점`
#
# - **(6-1)** 아래 코드에 에러가 나고 있습니다. 코드의 오류를 정정하세요.
#   - 대상 데이터프레임 : `data_temp`
#   - 지역(`region`)과 기기(`device`) 컬럼(범주형)의 결측치를 각 컬럼의 **최빈값(mode)**으로 채우세요
#   - 전처리가 반영된 데이터프레임은 `data_na`에 저장하세요
# - **(6-2)** `region` 컬럼의 최빈값은 무엇인가요?

# %%
# (6-1) 아래 코드의 오류를 정정하고 실행하세요
print( '결측치 처리 전\n', data_temp.isnull().sum() )
data_temp['region'] = data_temp['region'].fillna(data_temp['region'].mode())   # ← 오류: 최빈값 추출 정정
data_temp['device'] = data_temp['device'].fillna(data_temp['device'].mode())   # ← 오류: 최빈값 추출 정정
data_na = data_temp
print( '\n결측치 처리 후\n', data_na.isnull().sum() )


# (6-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 7. 원-핫 인코딩 (빈칸 채우기)  `7점`  ✏️ 빈칸 채우기
#
# - 대상 데이터프레임 : `data_na`
# - 원-핫 인코딩 대상 : `region`, `device`
# - 결과를 `data_preset`에 저장하고 `info()`로 검증하세요
# - 아래 코드 셀의 빈칸(`#7-1`, `#7-2`)을 채우고 실행하세요
# - **(7-3)** `data_preset`의 전체 컬럼 개수는 총 몇 개인가요?

# %%
# (7) 아래 빈칸(#7-1, #7-2)을 채우고 실행하세요
data_preset = pd.____(data=data_na, ____=['region', 'device'])  # #7-1 / #7-2
data_preset.info()


# (7-1) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (7-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (7-3) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 8. 타겟 인코딩 + 데이터 분리 + MinMaxScaler  `8점`
#
# - 대상 데이터프레임 : `data_preset`
# - 타겟 `membership_tier`를 `LabelEncoder`로 정수 인코딩하세요 (Bronze=0, Gold=1, Silver=2)
# - `membership_tier`를 레이블 `y`, 나머지를 피처 `X`로 할당하세요
# - 훈련:검증 = 80:20, 난수 시드 42, 등급 비율 유지(stratify)하여 분리 (`X_train`, `X_valid`, `y_train`, `y_valid`)
# - `MinMaxScaler`를 `ms` 변수에 지정 → 훈련데이터로 학습·변환, 검증데이터는 변환만 적용하세요
# - 마지막에 `X_train`, `X_valid`의 shape를 출력하세요

# %%
# (8) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 〈 AI 모델링 (50점) 〉
#
# ## 문제 9. DecisionTree + RandomForest 모델  `8점`
#
# 멤버십 등급(`membership_tier`)을 예측하는 머신러닝 모델을 만들려고 합니다.
# - **(9-1)** DecisionTree 모델을 `dt` 변수에 저장하고 훈련셋으로 학습하세요
#   - `max_depth=5`, `min_samples_split=3`, `random_state=42`
# - **(9-2)** RandomForest 모델을 `rf` 변수에 저장하고 훈련셋으로 학습하세요
#   - `n_estimators=100`, `max_depth=5`, `min_samples_split=3`, `random_state=42`

# %%
# (9-1) 여기에 답안코드를 작성하고 실행하세요


# (9-2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 문제 10. 다중분류 모델 평가 (오류 정정)  `8점`
#
# - **(10-1)** 아래 코드에 에러가 나고 있습니다. 코드의 오류를 정정하세요.
#   - 성능 평가는 검증데이터셋을 활용하세요
#   - 각 모델의 Accuracy를 `dt_acc`, `rf_acc`에, F1-score를 `dt_f1`, `rf_f1`에 저장하고 출력하세요
#   - **다중분류이므로 F1-score는 `average='macro'` 옵션을 사용하세요**
# - **(10-2)** 두 모델의 F1-score를 비교했을 때 더 우수한 모델은 무엇인가요?

# %%
# (10-1) 아래 코드의 오류를 정정하고 실행하세요
from sklearn.metrics import accuracy_score, f1_score
y_pred_dt = dt.predict(X_valid)
y_pred_rf = rf.predict(X_valid)
dt_acc = accuracy_score(y_valid, y_pred_dt)
rf_acc = accuracy_score(y_valid, y_pred_rf)
dt_f1 = f1_score(y_valid, y_pred_dt)   # ← 오류: 다중분류 average 옵션 추가
rf_f1 = f1_score(y_valid, y_pred_rf)   # ← 오류: 다중분류 average 옵션 추가
print(dt_acc, rf_acc, dt_f1, rf_f1)


# (10-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 11. classification_report (클래스별 성능)  `8점`
#
# 다중분류 모델의 클래스별 성능을 자세히 분석하려고 합니다.
# - 검증데이터에 대한 RandomForest 예측 결과로 `classification_report`를 출력하세요
# - `sklearn.metrics`의 `classification_report` 함수를 사용하세요
# - 각 등급(클래스)별 precision, recall, f1-score를 확인할 수 있습니다

# %%
# (11) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ▶ **다음 문항을 풀기 전에 아래 코드를 실행하세요.**

# %%
# 다음 문항을 풀기 전에 아래 코드를 실행하세요.
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
tf.random.set_seed(1)

# %% [markdown]
# ---
# ## 문제 12. 딥러닝 다중분류 모델 생성 및 학습  `8점`
#
# 멤버십 등급(`membership_tier`)을 예측하는 딥러닝 다중분류 모델을 만들려고 합니다. 아래 토폴로지와 가이드를 참고해 모델을 구성·학습하세요.
# - 아래 제시된 `to_categorical` 코드는 그대로 실행하여 타겟을 원-핫 벡터로 변환합니다 (실행 필수, 3개 클래스)
# - 하단 토폴로지와 동일한 모델을 구현하세요. 히든 `activation='relu'`, 출력 `activation='softmax'`(3노드)
# - `EarlyStopping`으로 5 epoch 동안 `val_loss`가 향상되지 않으면 중지하고 `estop`에 저장하세요
# - `optimizer='adam'`, `loss='categorical_crossentropy'`, `metrics=['accuracy']`로 컴파일하세요
# - `batch_size=32`, `epochs=50`으로 학습하고 학습정보는 `history`에 저장하세요
#
# **⊿ 모델 토폴로지**
#
# `입력층 → Dense(128, relu) → Dropout(0.3) → Dense(64, relu) → Dense(32, relu) → Dense(3, softmax)`

# %%
# 아래 to_categorical 코드는 그대로 실행하세요 (타겟 원-핫 변환, 3개 클래스)
y_train = to_categorical(y_train, num_classes=3)
y_valid = to_categorical(y_valid, num_classes=3)

# (12) 여기에 답안코드를 작성하고 실행하세요 (모델 구성 -> 컴파일 -> 학습)

# %% [markdown]
# ---
# ## 문제 13. 학습/검증 Accuracy 시각화  `8점`  ✏️ 빈칸 채우기
#
# matplotlib로 학습/검증 Accuracy의 변화를 그래프로 시각화하세요.
# - 1개의 그래프에 학습 Accuracy와 검증 Accuracy를 모두 표시하세요
# - 각각의 범례를 `'acc'`, `'val_acc'`로 표시하세요
# - 타이틀 `'Model Accuracy'`, X축 `'Epoch'`, Y축 `'Accuracy'`로 표시하세요
# - 아래 코드 셀의 빈칸(`#13-1`, `#13-2`)을 채우고 실행하세요

# %%
# (13) 아래 빈칸(#13-1, #13-2)을 채우고 실행하세요
plt.plot(____['accuracy'])         # #13-1
plt.plot(____['val_accuracy'])     # #13-1
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.____(['acc', 'val_acc'])       # #13-2
plt.show()


# (13-1) 여기에 답안을 입력하세요(실행 불필요)
# 답안 = 

# (13-2) 여기에 답안을 입력하세요(실행 불필요)
# 답안 =

# %% [markdown]
# ---
# ## 문제 14. 모델 저장/로드 후 신규 고객 등급 예측  `10점`
#
# 학습한 딥러닝 모델을 저장한 뒤, `load_model()`로 불러와 신규 고객의 멤버십 등급을 예측하려고 합니다.
# - 아래 제시된 신규 고객 데이터(`new_raw`)는 그대로 실행하세요 (예측 대상)
# - 학습한 `model`을 `'tier_model.keras'`로 저장한 뒤 `load_model()`로 불러오세요
# - `new_raw`를 학습 때와 동일하게 전처리하세요 (원-핫 인코딩 후 학습 피처 컬럼에 맞춰 정렬, 그 후 `ms`로 스케일링)
# - 불러온 모델로 예측한 확률에서 가장 높은 클래스를 선택해, 등급(Bronze/Silver/Gold)으로 출력하세요

# %%
# 아래 신규 고객 데이터(new_raw)는 그대로 실행하세요
new_raw = pd.DataFrame([
    {'age':41, 'tenure_months':60, 'num_orders':52, 'avg_order_value':14.0, 'num_reviews':22,
     'complaint_count':0, 'region':'Seoul', 'device':'PC'},
    {'age':27, 'tenure_months':6, 'num_orders':4, 'avg_order_value':5.0, 'num_reviews':1,
     'complaint_count':3, 'region':'Busan', 'device':'Mobile'},
])

# (14) 여기에 답안코드를 작성하고 실행하세요 (모델 저장 -> load_model -> new_raw 전처리 -> 예측 -> 등급 출력)

# %% [markdown]
# ---
# ### 모든 문항이 완료되었습니다. 수고하셨습니다. 🎉
#
# 정답 및 해설은 [AICE 모의고사 웹사이트](https://aice-exam.vercel.app)에서 확인하세요.
